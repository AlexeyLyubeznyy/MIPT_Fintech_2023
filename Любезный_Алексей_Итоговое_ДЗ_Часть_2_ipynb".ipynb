# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexeyLyubeznyy/MIPT_Fintech_2023/blob/main/%D0%9B%D1%8E%D0%B1%D0%B5%D0%B7%D0%BD%D1%8B%D0%B9_%D0%90%D0%BB%D0%B5%D0%BA%D1%81%D0%B5%D0%B9_%D0%98%D1%82%D0%BE%D0%B3%D0%BE%D0%B2%D0%BE%D0%B5_%D0%94%D0%97_%D0%A7%D0%B0%D1%81%D1%82%D1%8C_2_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Часть 2

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
hr = pd.read_csv('/content/drive/MyDrive/HR.csv')

# %%
hr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14999 entries, 0 to 14998
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   satisfaction_level     14999 non-null  float64
#  1   last_evaluation        14999 non-null  float64
#  2   number_project         14999 non-null  int64
#  3   average_montly_hours   14999 non-null  int64
#  4   time_spend_company     14999 non-null  int64
#  5   Work_accident          14999 non-null  int64
#  6   left                   14999 non-null  int64
#  7   promotion_last_5years  14999 non-null  int64
#  8   department             14999 non-null  object
#  9   salary                 14999 non-null  object
# dtypes: float64(2), int64(6), object(2)
# memory usage: 1.1+ MB

# %%
hr
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %% [markdown]
# **1.1. Посчитаем описательную статистику для признаков нашего датафрейма:**

# %%
hr.describe()
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# count        14999.000000     14999.000000    14999.000000
# mean             0.612834         0.716102        3.803054
# std              0.248631         0.171169        1.232592
# min              0.090000         0.360000        2.000000
# 25%              0.440000         0.560000        3.000000
# 50%              0.640000         0.720000        4.000000
# 75%              0.820000         0.870000        5.000000
# max              1.000000         1.000000        7.000000
#
#        average_montly_hours  time_spend_company  Work_accident          left  \
# count          14999.000000        14999.000000   14999.000000  14999.000000
# mean             201.050337            3.498233       0.144610      0.238083
# std               49.943099            1.460136       0.351719      0.425924
# min               96.000000            2.000000       0.000000      0.000000
# ...

# %% [markdown]
# **1.2. Посчитаем моду признаков в нашем датафрейме:**

# %%
hr.mode()
# Out:
#    satisfaction_level  last_evaluation  number_project  average_montly_hours  \
# 0                 0.1             0.55             4.0                   135
# 1                 NaN              NaN             NaN                   156
#
#    time_spend_company  Work_accident  left  promotion_last_5years department  \
# 0                 3.0            0.0   0.0                    0.0      sales
# 1                 NaN            NaN   NaN                    NaN        NaN
#
#   salary
# 0    low
# 1    NaN

# %% [markdown]
# **2. Корреляционная матрица:**

# %%
hr.corr()
# Out:
# <ipython-input-14-764b01c79bed>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   hr.corr()
#                        satisfaction_level  last_evaluation  number_project  \
# satisfaction_level               1.000000         0.105021       -0.142970
# last_evaluation                  0.105021         1.000000        0.349333
# number_project                  -0.142970         0.349333        1.000000
# average_montly_hours            -0.020048         0.339742        0.417211
# time_spend_company              -0.100866         0.131591        0.196786
# Work_accident                    0.058697        -0.007104       -0.004741
# left                            -0.388375         0.006567        0.023787
# promotion_last_5years            0.025605        -0.008684       -0.006064
#
# ...

# %% [markdown]
# Две самые скоррелированные переменные:

# %% [markdown]
# - number_project
# - average_montly_hours

# %%
print(hr.corr().abs().unstack().sort_values(kind="quicksort", ascending=False)[8:])
# Out:
# number_project         average_montly_hours     0.417211
# average_montly_hours   number_project           0.417211
# satisfaction_level     left                     0.388375
# left                   satisfaction_level       0.388375
# last_evaluation        number_project           0.349333
# number_project         last_evaluation          0.349333
# average_montly_hours   last_evaluation          0.339742
# last_evaluation        average_montly_hours     0.339742
# time_spend_company     number_project           0.196786
# number_project         time_spend_company       0.196786
# left                   Work_accident            0.154622
# Work_accident          left                     0.154622
# left                   time_spend_company       0.144822
# time_spend_company     left                     0.144822
# satisfaction_level     number_project           0.142970
# number_project         satisfaction_level       0.142970
# ...

# %% [markdown]
# Две наименее скоррелированные переменные:

# %% [markdown]
# - time_spend_company
# - Work_accident

# %% [markdown]
# **3. Посчитаем, сколько сотрудников работает в каждом департаменте:**

# %%
len(hr[hr['left'] == 1]) # посчитаем из любопытства число уволившихся сотрудников
# Out:
# 3571

# %%
hr_emp = hr[hr['left'] == 0] # оставляем в таблице только тех сотрудников, которые еще не уволились
hr_emp_pivot = pd.pivot_table(data=hr_emp, index='department', values='satisfaction_level', aggfunc='count').sort_values(by='satisfaction_level', ascending=False)
hr_emp_pivot.rename(columns={'satisfaction_level': 'employees'}, inplace=True)
hr_emp_pivot
# Out:
#              employees
# department
# sales             3126
# technical         2023
# support           1674
# IT                 954
# product_mng        704
# RandD              666
# marketing          655
# accounting         563
# management         539
# hr                 524

# %% [markdown]
# **4. Распределение сотрудников по зарплатам:**

# %%
hr_emp_salary = pd.pivot_table(data=hr_emp, index='salary', values='satisfaction_level', aggfunc='count')
hr_emp_salary.rename(columns={'satisfaction_level': 'employees'}, inplace=True)
hr_emp_salary
# Out:
#         employees
# salary
# high         1155
# low          5144
# medium       5129

# %%
plt.bar(hr_emp_salary.index, height=hr_emp_salary['employees'])
plt.xlabel('salary')
plt.ylabel('number of employees, people')
plt.title('Распределение сотрудников по зарплатам')
plt.show()

# %% [markdown]
# **5. Распределение сотрудников по зарплатам по каждому департаменту:**

# %%
hr_emp_salary_department = pd.pivot_table(data=hr_emp, index='department', columns='salary', values='satisfaction_level', aggfunc='count')
hr_emp_salary_department
# Out:
# salary       high   low  medium
# department
# IT             79   437     438
# RandD          47   309     310
# accounting     69   259     235
# hr             39   243     242
# management    224   121     194
# marketing      71   276     308
# product_mng    62   346     296
# sales         255  1402    1469
# support       133   757     784
# technical     176   994     853

# %% [markdown]
# **6. Проверим гипотезу, что сотрудники с высоким окладом проводят на работе больше времени, чем сотрудники с низким окладом:**

# %% [markdown]
# **Нулевая гипотеза:** сотрудники с высоким окладом проводят на работе столько же времени, сколько и сотрудники с низким окладом.
#
# **Альтернативная гипотеза:** сотрудники с высоким окладом проводят на работе больше времени, чем сотрудники с низким окладом.

# %%
high_paid = hr_emp.loc[hr_emp['salary'] == 'high', ['average_montly_hours']]
low_paid = hr_emp.loc[hr_emp['salary'] == 'low', ['average_montly_hours']]

# %%
print(np.var(high_paid), '\n', np.var(low_paid))
# Out:
# average_montly_hours    2166.443362
# dtype: float64
#  average_montly_hours    2068.78909
# dtype: float64

# %% [markdown]
# Отношение большей дисперсии выборки к меньшей дисперсии выборки меньше 4. Это означает, что мы можем использовать стандартный критерий Стьюдента, а не критерий Уэлча.

# %%
from statsmodels.stats.weightstats import ttest_ind

result = ttest_ind(high_paid, low_paid, alternative='larger')

print('t-statistic: ', result[0], '\n', 'p-value: ', result[1])
# Out:
# t-statistic:  [1.16335519]
#  p-value:  [0.12236475]

# %% [markdown]
# **Вывод:** нулевая гипотеза не отвергается. То есть по имеющимся данным нельзя сказать, что сотрудники с высоким окладом проводят на работе больше времени, чем сотрудники с низким окладом.

# %% [markdown]
# **7. Рассчитаем следующие показатели среди уволившихся и не уволившихся сотрудников (по отдельности):**

# %% [markdown]
# 7.1 Доля сотрудников с повышением за последние 5 лет

# %%
left = hr[hr['left'] == 1]

# %% [markdown]
# - Для уволившихся сотрудников

# %%
print("{:.2%}".format(len(left[left['promotion_last_5years'] == 1]) / len(left)))
# Out:
# 0.53%

# %% [markdown]
# - Для оставшихся сотрудников

# %%
print("{:.2%}".format(len(hr_emp[hr_emp['promotion_last_5years'] == 1]) / len(hr_emp)))
# Out:
# 2.63%

# %% [markdown]
# 7.2 Средняя степень удовлетворённости

# %% [markdown]
# - Для уволившихся сотрудников

# %%
print("{:.2}".format(left['satisfaction_level'].mean()))
# Out:
# 0.44

# %% [markdown]
# - Для оставшихся сотрудников

# %%
print("{:.2}".format(hr_emp['satisfaction_level'].mean()))
# Out:
# 0.67

# %% [markdown]
# 7.3 Среднее количество проектов

# %% [markdown]
# - Для уволившихся сотрудников

# %%
print("{:.2}".format(left['number_project'].mean()))
# Out:
# 3.9

# %% [markdown]
# - Для оставшихся сотрудников

# %%
print("{:.2}".format(hr_emp['number_project'].mean()))
# Out:
# 3.8

# %% [markdown]
# **8. Разделим данные на тестовую и обучающую выборку и построим модель LDA, которая показывает, уволился ли сотрудник на основе имеющихся факторов (кроме department и salary).**

# %%
from sklearn.model_selection import train_test_split

left_class = hr['left']
data = hr[['satisfaction_level', 'last_evaluation', 'number_project', 'average_montly_hours', 'time_spend_company', 'Work_accident', 'promotion_last_5years']]

X_train, X_test, y_train, y_test = train_test_split(data, left_class, test_size=0.2, random_state=42)

# %%
len(y_test)
# Out:
# 3000

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

lda = LinearDiscriminantAnalysis()

# %%
lda.fit(X_train, y_train)
# Out:
# LinearDiscriminantAnalysis()

# %%
lda.predict(X_test)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
result = pd.DataFrame([y_test, lda.predict(X_test)]).T

# %%
from sklearn.metrics import accuracy_score

accuracy_score(y_test, lda.predict(X_test))
# Out:
# 0.7533333333333333
